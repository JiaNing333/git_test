# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
url = 'https://www.findcoupon.tw/showroom-1074/store/%E6%96%B0%E5%8C%97%E5%B8%82'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
# <head>
# <meta charset="utf-8"/>
# <title>【cama咖啡】新北市分店門市/服務據點 - 找優惠</title>
# <meta content="【cama咖啡】新北市分店門市/服務據點 - 找優惠" property="og:title"/>
# <meta content="IE=edge,Chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="www.findcoupon.tw" name="copyright"/>
# <meta content="www.findcoupon.tw" name="generator"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="【cama咖啡】新北市分店門市/服務據點" name="keywords"/>
# <meta content="INDEX, FOLLOW" name="robots"/>
# <meta content="【cama咖啡】新北市分店門市/服務據點" name="description"/>
# <meta content="【cama咖啡】新北市分店門市/服務據點" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="找優惠" property="og:site_name"/>
# <link href="https://www.findcoupon.tw/showroom-1074/store/新北市" rel="canonical"/>
# <link href="https://www.findcoupon.tw/showroom-1074/store/新北市" hreflang="x-default" rel="alternate"/>
# <link href="https://www.findcoupon.tw/showroom-1074/store/新北市" hreflang="zh-TW" rel="alternate"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//images.weserv.nl" rel="dns-prefetch"/>
# <link href="//oss.maxcdn.com" rel="dns-prefetch"/>
# <link href="//img.findcoupon.tw" rel="dns-prefetch"/>
# <link href="//scontent.xx.fbcdn.net" rel="dns-prefetch"/>
# <link href="//rec.scupio.com" rel="dns-prefetch"/>
# <link href="//www.facebook.com" rel="dns-prefetch"/>
# <link href="//connect.facebook.net" rel="dns-prefetch"/>
# <link href="//use.fontawesome.com" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# <link crossorigin="anonymous" href="//use.fontawesome.com/releases/v5.2.0/css/all.css" integrity="sha384-hWVjflwFxL6sNzntih27bfxkr27PmbbK/iSvJ+a4+0owXq79v+lsFkW54bOGbiDQ" rel="stylesheet"/>
# <!--
# 	<link rel="stylesheet" type="text/css" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css">-->
# <!-- Custom CSS -->
# <link href="/plugins/jquery/swiper/dist/css/min-JVBSnsd1eQnTIwEdwh7YUQLLnz-ue5Ei1nsjy2gJ2vba4x8EBQB-Ido2KMhWNLV2.css" rel="stylesheet" type="text/css"/><link href="/media/css/min-8NJZpplopCMJbbwW0293gcmgp6X6NtIYo8cxSlyFNMTkEkum7OwBcEU-KkNkUZRDQ5NIZypty67znFMTMDvGqaT_DQ24FH88ORNVKK_JqxPznFMTMDvGqVNX4aTKIm0KmStk6YXkaL4.css" rel="stylesheet" type="text/css"/><link href="/themes/default/css/min-Qd0rYumStz2ASw5izO0YLGBxEBxQ-qKCcSvCaIjW9FNi-jnbw0qpSZvfHdtmbRqkl5dw0hTw1499XqoK9Ix2LFsxsxJgMBtv1497CVGZferx58wU-aq_UGGrdQSYLP0ILrGfXb5xjfSPx0wixduKJ4_hyfA8OP9etLVywzJsMNDshVGtZ1qIIitomgKsgrbXiO1zvzrpKLu0tXLDMmww0OyFUa1nWogi-fawdTN0Yo6CrdyMe4shQmJ2GV4zT89R.css" rel="stylesheet" type="text/css"/>
# <!-- HTML5 shim and Respond.js 讓 IE8 支援 HTML5 元素與媒體查詢 -->
# <!-- 警告：Respond.js 無法在 file:// 協定下運作 -->
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js" type="text/javascript"></script>
# <script src="//code.jquery.com/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-7306347511045995"></script></head>
# <body>
# <div class="wrapper" id="wrapper">
# <div id="content-wrapper">
# <!-- #header -->
# <header class="headerWrap clearfix" itemscope="" itemtype="http://www.schema.org/WPHeader">
# <div class="navbar-inverse logoWrap clearfix" id="header1">
# <div class="container">
# <div class="row">
# <div class="col-md-3 col-sm-3 col-xs-6 logo-box">
# <span class="mobile-logo-box">
# <span class="fa fa-bars sidebar-icon"></span>
# </span>
# <a class="logo" href="/"><img alt="找優惠" src="/themes/findcoupon/images/logo.png"/></a>
# </div>
# <div class="col-md-7 col-sm-7 col-xs-6 navbar-collapse collapse">
# <ul class="nav navbar-nav">
# <li class=""><a href="/"><i class="fa fa-home"></i> 首頁</a>
# </li>
# <li class=""><a href="/news"><i class="fa fa-newspaper"></i> 優惠活動</a>
# </li>
# <li class=""><a href="/dm"><i class="fa fa-desktop"></i> 線上DM</a>
# </li>
# <li class="active"><a href="/brand/1"><i class="fa fa-bullseye"></i> 品牌總覽</a>
# </li>
# </ul>
# </div>
# <div class="col-md-2 col-sm-2 col-xs-6 search-box pull-right">
# <a class="search-icon" data-target="#modal-search" data-toggle="modal" href="javascript:void(0);"><i class="fa fa-search"></i></a>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="modal modal-full modal-half" id="modal-search" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header fixed">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title">搜尋</h4>
# </div>
# <div class="modal-body mgt40 bgeee">
# <form action="/s" class="search-form" method="get">
# <input class="search-input" id="q" name="q" placeholder="請輸入關鍵字" type="search" value=""/>
# <a class="search-clear" href="javascript:void(0);" title="清除"><i class="fa fa-close pure-round"></i></a>
# <button class="search-submit" id="search-submit" type="submit"><i class="fa fa-search"></i></button>
# </form> <div class="hot-keyword">
# <!--<span>歷史紀錄：</span>--->
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- #nav -->
# <div class="sh-cover">
# <div class="container">
# <div class="row">
# <div class="sh-cover-wrap clearfix">
# <div class="sh-cover-logo">
# <img src="/uploads/logo/1000/1074.png"/>
# </div>
# <div class="sh-cover-info">
# <h2 class="sh-name ellipsis">cama咖啡</h2>
# <p>
# <a href="http://www.camacafe.com/?utm_source=findcoupon.tw&amp;utm_medium=event&amp;utm_campaign=news&amp;utm_content=%2Fshowroom-1074%2Fstore%2F%E6%96%B0%E5%8C%97%E5%B8%82" rel="noopener nofollow" target="_blank"><i class="fa fa-globe"></i> 官網</a>
# <a href="/brand/4" rel="noopener" target="_blank"><i class="fa fa-folder"></i> 咖啡店</a>
# <!--<span><i class="fa fa-thumbs-o-up"></i> 1,568,825</span>-->
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sh-menu">
# <div class="container">
# <div class="row">
# <div class="sh-menu-wrap swiper-nav swiper-nav2 clearfix">
# <nav class="swiper-container">
# <ul class="swiper-wrapper">
# <!--			<li class="swiper-slide s_logo" style="float:left;border-right:1px solid #e9eaed;padding-right:5px;visibility: hidden;"><img src="/uploads/logo/1000/1074.png" width=35 height=35 >
# 			</li>
# 			-->
# <li class="swiper-slide"><a href="/showroom-1074">  首頁</a></li>
# <li class="swiper-slide"><a href="/showroom-1074/news">  優惠活動</a></li>
# <li class="swiper-slide"><a href="/showroom-1074/menu">  菜單</a></li>
# <li class="swiper-slide active-li"><a href="/showroom-1074/store">  分店門市</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <script>
# $(function () {
# 	start_swiper_nav('.swiper-nav2');
# });
# </script>
# <div id="fb-root"></div>
# <script>
# (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.7&appId=230626213615077";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
# </script>
# <!-- #breadcrumb -->
# <div class="clearfix" id="breadcrumb">
# <div class="container">
# <div class="row">
# <ul class="breadcrumb ellipsis ellipsis-clamp2">
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="https://www.findcoupon.tw" itemprop="url" title="找優惠"><i class="fa fa-home"></i><span class="hide" itemprop="title"> 找優惠</span></a></li>
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/showroom-1074" itemprop="url"><span itemprop="title">cama咖啡</span></a></li><li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/showroom-1074/store" itemprop="url"><span itemprop="title">分店門市</span></a></li>
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="https://www.findcoupon.tw/showroom-1074/store/新北市" itemprop="url" title="新北市"><h1 itemprop="title">新北市</h1></a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- content -->
# <main class="container">
# <style>
# .form-select {
#     -moz-border-radius: 2px;
#     -webkit-border-radius: 2px;
#     border-radius: 2px;
#     font-family: Roboto,Arial,sans-serif,"微軟正黑體","Microsoft JhengHei","新細明體";
#     font-weight: normal;
#     font-size: 14px;
#     color: #333;
#     background: #fff;
#     border: 1px solid #e5e5e5;
#     padding: 3px 3px;
#     cursor: pointer;
# }
# .location-map--heading {
#     display: inline-block;
#     margin: 0;
#     padding: 10px 10px;
#     background: #eee;
# 	width:100%;
# 	font-weight: bold;
# 	font-size: 16px;
# }
#
# /* style="border-bottom:1px dotted #d8d8d8;"*/
#
# .css-table {
# 	word-wrap: normal!important;
# }
# </style>
# <div class="box box-default">
# <div class="box-header">
# <form action="" id="form2" name="form2">
# <span class="box-liner llinered3"></span>
# <h3 class="box-title colorred">區域：</h3>
# <select class="form-select level_2" name="level_2" onchange="submit_city();">
# <option value="全部縣市">全部縣市(131)</option><option value="台北市">台北市(61)</option><option selected="" value="新北市">新北市(19)</option><option value="新竹市">新竹市(5)</option><option value="新竹縣">新竹縣(3)</option><option value="桃園市">桃園市(10)</option><option value="苗栗縣">苗栗縣(1)</option><option value="台中市">台中市(10)</option><option value="彰化縣">彰化縣(4)</option><option value="嘉義市">嘉義市(1)</option><option value="台南市">台南市(3)</option><option value="高雄市">高雄市(9)</option><option value="屏東縣">屏東縣(1)</option><option value="宜蘭縣">宜蘭縣(1)</option><option value="花蓮縣">花蓮縣(2)</option><option value="澎湖縣">澎湖縣(1)</option> </select>
# <select class="form-select level_3" name="level_3" onchange="submit_from();">
# <option value="">-- 全部區域 --</option><option value="板橋區">板橋區(5)</option><option value="汐止區">汐止區(1)</option><option value="新店區">新店區(3)</option><option value="永和區">永和區(4)</option><option value="中和區">中和區(4)</option><option value="蘆洲區">蘆洲區(1)</option><option value="淡水區">淡水區(1)</option> </select>
# </form>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <div class="box-body box box-default">
# <div class="css-table" id="css-table">
# <div class="thead">
# <div class="tr">
# <div class="th">店名</div>
# <div class="th">地址</div>
# <div class="th">電話</div>
# </div>
# </div>
# <div class="tbody">
# <div class="tr">
# <div class="td"><a href="/store-3698.htm">四號公園店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區中安街24號')"><i class="fa fa-map-marker"></i> 新北市中和區中安街24號</a></div> -->
# <div class="td"><a href="/store-3698.htm"><i class="fa fa-map-marker"></i> 新北市中和區中安街24號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區中安街24號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2929-6691"><i class="fa fa-phone"></i> 02-2929-6691</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3696.htm">中和環球店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區中山路三段99號')"><i class="fa fa-map-marker"></i> 新北市中和區中山路三段99號</a></div> -->
# <div class="td"><a href="/store-3696.htm"><i class="fa fa-map-marker"></i> 新北市中和區中山路三段99號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區中山路三段99號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-22213588"><i class="fa fa-phone"></i> 02-22213588</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3697.htm">中和立言店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區中正路903之1號')"><i class="fa fa-map-marker"></i> 新北市中和區中正路903之1號</a></div> -->
# <div class="td"><a href="/store-3697.htm"><i class="fa fa-map-marker"></i> 新北市中和區中正路903之1號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區中正路903之1號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2221-3277"><i class="fa fa-phone"></i> 02-2221-3277</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27291.htm">中和泰和店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區泰和街39號1樓')"><i class="fa fa-map-marker"></i> 新北市中和區泰和街39號1樓</a></div> -->
# <div class="td"><a href="/store-27291.htm"><i class="fa fa-map-marker"></i> 新北市中和區泰和街39號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區泰和街39號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2240-3699"><i class="fa fa-phone"></i> 02-2240-3699</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3691.htm">新店七張店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市新店區北新路二段218號')"><i class="fa fa-map-marker"></i> 新北市新店區北新路二段218號</a></div> -->
# <div class="td"><a href="/store-3691.htm"><i class="fa fa-map-marker"></i> 新北市新店區北新路二段218號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市新店區北新路二段218號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2910-3508"><i class="fa fa-phone"></i> 02-2910-3508</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3692.htm">新店寶橋店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市新店區寶橋路214號')"><i class="fa fa-map-marker"></i> 新北市新店區寶橋路214號</a></div> -->
# <div class="td"><a href="/store-3692.htm"><i class="fa fa-map-marker"></i> 新北市新店區寶橋路214號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市新店區寶橋路214號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2912-9970"><i class="fa fa-phone"></i> 02-2912-9970</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27297.htm">新店民權店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市新店區民權路96號1樓')"><i class="fa fa-map-marker"></i> 新北市新店區民權路96號1樓</a></div> -->
# <div class="td"><a href="/store-27297.htm"><i class="fa fa-map-marker"></i> 新北市新店區民權路96號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市新店區民權路96號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2218-5000"><i class="fa fa-phone"></i> 02-2218-5000</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3689.htm">板橋三民店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區三民路二段67號')"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號</a></div> -->
# <div class="td"><a href="/store-3689.htm"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區三民路二段67號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-29580101"><i class="fa fa-phone"></i> 02-29580101</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27294.htm">板橋三民店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區三民路二段67號1樓')"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號1樓</a></div> -->
# <div class="td"><a href="/store-27294.htm"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區三民路二段67號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2958-0101"><i class="fa fa-phone"></i> 02-2958-0101</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3690.htm">板橋亞東店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區南雅南路二段21號Ｂ1')"><i class="fa fa-map-marker"></i> 新北市板橋區南雅南路二段21號Ｂ1</a></div> -->
# <div class="td"><a href="/store-3690.htm"><i class="fa fa-map-marker"></i> 新北市板橋區南雅南路二段21號Ｂ1</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區南雅南路二段21號Ｂ1" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-8966-8333"><i class="fa fa-phone"></i> 02-8966-8333</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27295.htm">板橋文化店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區文化路二段402號')"><i class="fa fa-map-marker"></i> 新北市板橋區文化路二段402號</a></div> -->
# <div class="td"><a href="/store-27295.htm"><i class="fa fa-map-marker"></i> 新北市板橋區文化路二段402號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區文化路二段402號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-22586227"><i class="fa fa-phone"></i> 02-22586227</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27296.htm">板橋正隆店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區板新路一號')"><i class="fa fa-map-marker"></i> 新北市板橋區板新路一號</a></div> -->
# <div class="td"><a href="/store-27296.htm"><i class="fa fa-map-marker"></i> 新北市板橋區板新路一號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區板新路一號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2961-6089"><i class="fa fa-phone"></i> 02-2961-6089</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3693.htm">永和中山店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區中山路一段220號')"><i class="fa fa-map-marker"></i> 新北市永和區中山路一段220號</a></div> -->
# <div class="td"><a href="/store-3693.htm"><i class="fa fa-map-marker"></i> 新北市永和區中山路一段220號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區中山路一段220號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2231-1119"><i class="fa fa-phone"></i> 02-2231-1119</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27292.htm">永和耕莘店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區中興街83號')"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號</a></div> -->
# <div class="td"><a href="/store-27292.htm"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區中興街83號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2920-6888"><i class="fa fa-phone"></i> 02-2920-6888</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3694.htm">永和耕莘店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區中興街83號1樓')"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號1樓</a></div> -->
# <div class="td"><a href="/store-3694.htm"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區中興街83號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-29206888"><i class="fa fa-phone"></i> 02-29206888</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3695.htm">永和福和店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區福和路271號')"><i class="fa fa-map-marker"></i> 新北市永和區福和路271號</a></div> -->
# <div class="td"><a href="/store-3695.htm"><i class="fa fa-map-marker"></i> 新北市永和區福和路271號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區福和路271號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2231-1823"><i class="fa fa-phone"></i> 02-2231-1823</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-27293.htm">汐止遠雄店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市汐止區新台五路一段99號B1')"><i class="fa fa-map-marker"></i> 新北市汐止區新台五路一段99號B1</a></div> -->
# <div class="td"><a href="/store-27293.htm"><i class="fa fa-map-marker"></i> 新北市汐止區新台五路一段99號B1</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市汐止區新台五路一段99號B1" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2697-6333"><i class="fa fa-phone"></i> 02-2697-6333</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3700.htm">淡水新市店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市淡水區中山北路二段201號')"><i class="fa fa-map-marker"></i> 新北市淡水區中山北路二段201號</a></div> -->
# <div class="td"><a href="/store-3700.htm"><i class="fa fa-map-marker"></i> 新北市淡水區中山北路二段201號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市淡水區中山北路二段201號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2623-9927"><i class="fa fa-phone"></i> 02-2623-9927</a></div>
# </div>
# <div class="tr">
# <div class="td"><a href="/store-3699.htm">蘆洲長榮店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市蘆洲區長榮路201號')"><i class="fa fa-map-marker"></i> 新北市蘆洲區長榮路201號</a></div> -->
# <div class="td"><a href="/store-3699.htm"><i class="fa fa-map-marker"></i> 新北市蘆洲區長榮路201號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市蘆洲區長榮路201號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-8286-3832"><i class="fa fa-phone"></i> 02-8286-3832</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
# function submit_city(){
# 	//$('.level_2 option').prop('selected', false);
# 	//$('.level_3 option').prop('selected', false);
# 	//form2.submit();
# 	//var param_str = $('#form2').serialize();
# 	//console.log(param_str);
# 	//var send_url  = "?mod=ajax&" + param_str;
# }
#
# var url = "/showroom-1074/store";
#
# function submit_city() {
# 	var city = $('.level_2').val();
#
# 	if(typeof(city) != "undefined" && city != "全部縣市"){
# 		url+= "/"+city;
# 	}
# 	location.href = url;
# 	return false;
# }
#
# function submit_from() {
# 	var city = $('.level_2').val();
# 	var area = $('.level_3').val();
#
# 	if(typeof(city) != "undefined" && city != "全部縣市" && city != ""){
# 		url+= "/"+city;
# 	}
#
# 	if(typeof(area) != "undefined" && area != "全部區域" && area != ""){
# 		url+= "/"+area;
# 	}
# 	location.href = url;
# 	return false;
# }
# </script>
# </main>
# <div class="container mgb20">
# <div class="row">
# <div class="col-xs-12">
# <!-- 底部 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-7306347511045995" data-ad-format="auto" data-ad-slot="7302348985" data-full-width-responsive="true" style="display:block"></ins>
# <script>
# 								 (adsbygoogle = window.adsbygoogle || []).push({});
# 							</script>
# </div>
# </div>
# </div>
# <!-- scupio -->
# <div class="container mgb20">
# <div class="row">
# <div class="col-xs-12">
# <ins class="scupioadslot" data-sca-category="24" data-sca-cid="19098" data-sca-pub="lRwEEwIq" data-sca-slot-type="STA" data-sca-web="5292" style="display:inline-block;width:728px;height:90px;"></ins>
# <script async="" src="https://img.scupio.com/js/ad.js"></script>
# </div>
# </div>
# </div>
# <!-- PCHOME
# 				<div class="container mgb20">
# 					<div class="row" >
# 						<div class="col-xs-12">
# 							<script language="javascript">
# 							pad_width=728;
# 							pad_height=90;
# 							pad_customerId="PFBC20170110002";
# 							pad_positionId="PFBP202111120001C";
# 							</script>
# 							<script id="pcadscript" language="javascript" src="https://kdpic.pchome.com.tw/img/js/xpcadshow.js"></script>
#
# 						</div>
# 					</div>
# 				</div>-->
# <!-- #footer -->
# <footer class="footer-wrapper">
# <div class="container">
# <div class="row">
# <div class="col-md-8">
# <p class="footer-menu">
# <a href="/">首頁</a>
# 					· <a href="/html/about_us.htm">關於我們</a>
# 					· <a href="/html/policy.htm">隱私權政策</a>
# 					· <a href="/html/copyright.htm">版權聲明</a>
# 					· <a href="/html/contact_us.htm">加入我們</a>
# 					· <a href="/html/contact_us.htm">聯絡我們</a>
# 										· <a href="https://www.instagram.com/findcoupon" target="_blank" title="找優惠 Instagram"><i class="fab fa-instagram" style="font-size:15px; color:#f4555a;"></i></a>
# <a href="https://www.facebook.com/findcoupon" target="_blank" title="找優惠 Facebook"><i class="fab fa-facebook-square" style="font-size:15px; color:#4267b2;"></i></a>
# </p>
# </div>
# <div class="col-md-4">
# <p class="footer-copyright">
# 					© 2021 <a href="https://www.findcoupon.tw" title="找優惠">找優惠</a> All Rights Reserved.
# 					<a href="https://line.me/R/ti/p/%40ykb1236d" rel="nofollow" target="_blank"><img alt="加入好友" border="0" height="36" src="https://scdn.line-apps.com/n/line_add_friends/btn/zh-Hant.png"/></a>
# </p>
# </div>
# </div>
# </div>
# </footer>
# <!--
# <ul class="menu-float">
#     <li class="block block1"><a href="/" title="Home"><i class="fa fa-home" aria-hidden="true"></i><p class="rwd">首頁</p></a></li>
#     <li class="block block2"><a href="/news"><i class="fa fa-newspaper-o" aria-hidden="true"></i><p class="rwd">優惠活動</p></a></li>
#     <li class="block block4"><a href="/dm" title=""><i class="fa fa-desktop" aria-hidden="true"></i><p class="rwd">DM情報</p></a></li>
#     <li class="block block3"><a href="/brand" title=""><i class="fa fa-bullseye" aria-hidden="true"></i><p class="rwd">所有品牌</p></a></li>
# </ul>
# -->
# </div>
# <!-- #mobile -->
# <div id="sidebar-wrapper">
# <div class="sidebar-area">
# <span class="fa fa-times fa-2x sidebar-close"></span>
# <div align="center" class="sidebar-brand">
# <span class="fa fa-4x fa-tags" id="logo"></span>
# <span class="sidebar-brandname">找優惠</span>
# <!--<a href="/"><img src="/" /></a>-->
# </div>
# <!-- <div style="height:1px;width:100%;background-color: #bbb; margin:10px 0 ;"></div> -->
# <ul class="sidebar-nav"></ul>
# </div>
# </div>
# <script>
# 	$(".sidebar-nav").html($(".navbar-nav").html());
# </script></div>
# <p id="back-top">
# <a href="#top" title="回頂部"> <span> </span> </a>
# </p>
# <div id="overlay"></div>
# <script src="/jsmin-JVBSnsd1eQmYfG_aPb0HlLEMYTSxLx8XF4TzPbg473AGck_k2SM-zTpae_Lu4E3rk9bb7iUgVIEgvuIFA9EUYV2EPgF47xW_fN8f7VQYZ2Yk96mKgobibbErRibR7j0BojTRI4mln6aNpHBJ6ddlRMKqahGwBnvZ-FaZG0oNVIB2wvZ4bLWDzFSptVFLmGrZJVBSnsd1eQnTIwEdwh7YUQLLnz-ue5EiPE3AE8JQteTbF9xM63jjkzpae_Lu4E3rk9bb7iUgVIHE-CkMgJ9riXutHewiV-ldOlp74u7gTeuT1tvuJSBUgcT8KQyAn2uJ979_0uB1ii0uTj8lGGP7a3lUdj20VZ3haaRM4VKdGRVBVVLelVDLkO-f89Hwzki5fq98i1yhdX0yuPjObvWNuIsY-2LTRZS4rOvWruBsAAhjT2uNHi04aicjRtUl9vIIIFwVr9sXhBQusZ9dvnGN9Dd8vSXwIVfNy1RtCfzvUXV9XqoK9Ix2LFsxsxJgMBtvoyt-k041M05KQ9TfY0vW9w.js" type="text/javascript"></script><script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-15256499-38', 'auto');
# 	ga('send', 'pageview');
# </script>
# </body>
# </html>

# %%
st = soup.find_all("div",class_ = 'tr')
print(st)
print(type(st))
# Out:
# [<div class="tr">
# <div class="th">店名</div>
# <div class="th">地址</div>
# <div class="th">電話</div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3698.htm">四號公園店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區中安街24號')"><i class="fa fa-map-marker"></i> 新北市中和區中安街24號</a></div> -->
# <div class="td"><a href="/store-3698.htm"><i class="fa fa-map-marker"></i> 新北市中和區中安街24號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區中安街24號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2929-6691"><i class="fa fa-phone"></i> 02-2929-6691</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3696.htm">中和環球店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區中山路三段99號')"><i class="fa fa-map-marker"></i> 新北市中和區中山路三段99號</a></div> -->
# <div class="td"><a href="/store-3696.htm"><i class="fa fa-map-marker"></i> 新北市中和區中山路三段99號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區中山路三段99號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-22213588"><i class="fa fa-phone"></i> 02-22213588</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3697.htm">中和立言店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區中正路903之1號')"><i class="fa fa-map-marker"></i> 新北市中和區中正路903之1號</a></div> -->
# <div class="td"><a href="/store-3697.htm"><i class="fa fa-map-marker"></i> 新北市中和區中正路903之1號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區中正路903之1號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2221-3277"><i class="fa fa-phone"></i> 02-2221-3277</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27291.htm">中和泰和店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市中和區泰和街39號1樓')"><i class="fa fa-map-marker"></i> 新北市中和區泰和街39號1樓</a></div> -->
# <div class="td"><a href="/store-27291.htm"><i class="fa fa-map-marker"></i> 新北市中和區泰和街39號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市中和區泰和街39號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2240-3699"><i class="fa fa-phone"></i> 02-2240-3699</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3691.htm">新店七張店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市新店區北新路二段218號')"><i class="fa fa-map-marker"></i> 新北市新店區北新路二段218號</a></div> -->
# <div class="td"><a href="/store-3691.htm"><i class="fa fa-map-marker"></i> 新北市新店區北新路二段218號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市新店區北新路二段218號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2910-3508"><i class="fa fa-phone"></i> 02-2910-3508</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3692.htm">新店寶橋店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市新店區寶橋路214號')"><i class="fa fa-map-marker"></i> 新北市新店區寶橋路214號</a></div> -->
# <div class="td"><a href="/store-3692.htm"><i class="fa fa-map-marker"></i> 新北市新店區寶橋路214號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市新店區寶橋路214號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2912-9970"><i class="fa fa-phone"></i> 02-2912-9970</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27297.htm">新店民權店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市新店區民權路96號1樓')"><i class="fa fa-map-marker"></i> 新北市新店區民權路96號1樓</a></div> -->
# <div class="td"><a href="/store-27297.htm"><i class="fa fa-map-marker"></i> 新北市新店區民權路96號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市新店區民權路96號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2218-5000"><i class="fa fa-phone"></i> 02-2218-5000</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3689.htm">板橋三民店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區三民路二段67號')"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號</a></div> -->
# <div class="td"><a href="/store-3689.htm"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區三民路二段67號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-29580101"><i class="fa fa-phone"></i> 02-29580101</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27294.htm">板橋三民店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區三民路二段67號1樓')"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號1樓</a></div> -->
# <div class="td"><a href="/store-27294.htm"><i class="fa fa-map-marker"></i> 新北市板橋區三民路二段67號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區三民路二段67號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2958-0101"><i class="fa fa-phone"></i> 02-2958-0101</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3690.htm">板橋亞東店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區南雅南路二段21號Ｂ1')"><i class="fa fa-map-marker"></i> 新北市板橋區南雅南路二段21號Ｂ1</a></div> -->
# <div class="td"><a href="/store-3690.htm"><i class="fa fa-map-marker"></i> 新北市板橋區南雅南路二段21號Ｂ1</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區南雅南路二段21號Ｂ1" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-8966-8333"><i class="fa fa-phone"></i> 02-8966-8333</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27295.htm">板橋文化店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區文化路二段402號')"><i class="fa fa-map-marker"></i> 新北市板橋區文化路二段402號</a></div> -->
# <div class="td"><a href="/store-27295.htm"><i class="fa fa-map-marker"></i> 新北市板橋區文化路二段402號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區文化路二段402號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-22586227"><i class="fa fa-phone"></i> 02-22586227</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27296.htm">板橋正隆店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市板橋區板新路一號')"><i class="fa fa-map-marker"></i> 新北市板橋區板新路一號</a></div> -->
# <div class="td"><a href="/store-27296.htm"><i class="fa fa-map-marker"></i> 新北市板橋區板新路一號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市板橋區板新路一號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2961-6089"><i class="fa fa-phone"></i> 02-2961-6089</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3693.htm">永和中山店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區中山路一段220號')"><i class="fa fa-map-marker"></i> 新北市永和區中山路一段220號</a></div> -->
# <div class="td"><a href="/store-3693.htm"><i class="fa fa-map-marker"></i> 新北市永和區中山路一段220號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區中山路一段220號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2231-1119"><i class="fa fa-phone"></i> 02-2231-1119</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27292.htm">永和耕莘店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區中興街83號')"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號</a></div> -->
# <div class="td"><a href="/store-27292.htm"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區中興街83號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2920-6888"><i class="fa fa-phone"></i> 02-2920-6888</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3694.htm">永和耕莘店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區中興街83號1樓')"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號1樓</a></div> -->
# <div class="td"><a href="/store-3694.htm"><i class="fa fa-map-marker"></i> 新北市永和區中興街83號1樓</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區中興街83號1樓" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-29206888"><i class="fa fa-phone"></i> 02-29206888</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3695.htm">永和福和店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市永和區福和路271號')"><i class="fa fa-map-marker"></i> 新北市永和區福和路271號</a></div> -->
# <div class="td"><a href="/store-3695.htm"><i class="fa fa-map-marker"></i> 新北市永和區福和路271號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市永和區福和路271號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2231-1823"><i class="fa fa-phone"></i> 02-2231-1823</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-27293.htm">汐止遠雄店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市汐止區新台五路一段99號B1')"><i class="fa fa-map-marker"></i> 新北市汐止區新台五路一段99號B1</a></div> -->
# <div class="td"><a href="/store-27293.htm"><i class="fa fa-map-marker"></i> 新北市汐止區新台五路一段99號B1</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市汐止區新台五路一段99號B1" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2697-6333"><i class="fa fa-phone"></i> 02-2697-6333</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3700.htm">淡水新市店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市淡水區中山北路二段201號')"><i class="fa fa-map-marker"></i> 新北市淡水區中山北路二段201號</a></div> -->
# <div class="td"><a href="/store-3700.htm"><i class="fa fa-map-marker"></i> 新北市淡水區中山北路二段201號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市淡水區中山北路二段201號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-2623-9927"><i class="fa fa-phone"></i> 02-2623-9927</a></div>
# </div>, <div class="tr">
# <div class="td"><a href="/store-3699.htm">蘆洲長榮店</a></div>
# <!--<div class="td"> <a href="javascript:submit_map('新北市蘆洲區長榮路201號')"><i class="fa fa-map-marker"></i> 新北市蘆洲區長榮路201號</a></div> -->
# <div class="td"><a href="/store-3699.htm"><i class="fa fa-map-marker"></i> 新北市蘆洲區長榮路201號</a> <a href="https://maps.google.com.tw/maps?hl=zh-TW&amp;output=embed&amp;z=16&amp;t=地圖模式&amp;q=新北市蘆洲區長榮路201號" rel="nofollow" target="_blank"><span class="label label-default">Map</span></a></div>
# <div class="td"><a href="tel:02-8286-3832"><i class="fa fa-phone"></i> 02-8286-3832</a></div>
# </div>]
# <class 'bs4.element.ResultSet'>

# %%
import json
import pprint as pp
stlist = []

st = soup.select("div.tr > div.td")
# print(soup.select_one("div.tr > div.td").get_text())

for sts in st:
    stlist.append(sts.get_text())
# print(stlist)

def split_list(stlist, n):
    for idx in range(0,len(stlist),n):
        yield stlist[idx:idx+n]
        
stbks = list(split_list(stlist,3))
pp.pprint(stbks)

def saveJson():
    file = open("NTC_cama.json", "w", encoding="utf-8")
    file.write(json.dumps(stbks, ensure_ascii=False))
    file.close() 
    
if __name__ == "__main__":
    saveJson()
# Out:
# [['四號公園店', ' 新北市中和區中安街24號 Map', ' 02-2929-6691'],
#  ['中和環球店', ' 新北市中和區中山路三段99號 Map', ' 02-22213588'],
#  ['中和立言店', ' 新北市中和區中正路903之1號 Map', ' 02-2221-3277'],
#  ['中和泰和店', ' 新北市中和區泰和街39號1樓 Map', ' 02-2240-3699'],
#  ['新店七張店', ' 新北市新店區北新路二段218號 Map', ' 02-2910-3508'],
#  ['新店寶橋店', ' 新北市新店區寶橋路214號 Map', ' 02-2912-9970'],
#  ['新店民權店', ' 新北市新店區民權路96號1樓 Map', ' 02-2218-5000'],
#  ['板橋三民店', ' 新北市板橋區三民路二段67號 Map', ' 02-29580101'],
#  ['板橋三民店', ' 新北市板橋區三民路二段67號1樓 Map', ' 02-2958-0101'],
#  ['板橋亞東店', ' 新北市板橋區南雅南路二段21號Ｂ1 Map', ' 02-8966-8333'],
#  ['板橋文化店', ' 新北市板橋區文化路二段402號 Map', ' 02-22586227'],
#  ['板橋正隆店', ' 新北市板橋區板新路一號 Map', ' 02-2961-6089'],
#  ['永和中山店', ' 新北市永和區中山路一段220號 Map', ' 02-2231-1119'],
#  ['永和耕莘店', ' 新北市永和區中興街83號 Map', ' 02-2920-6888'],
#  ['永和耕莘店', ' 新北市永和區中興街83號1樓 Map', ' 02-29206888'],
#  ['永和福和店', ' 新北市永和區福和路271號 Map', ' 02-2231-1823'],
#  ['汐止遠雄店', ' 新北市汐止區新台五路一段99號B1 Map', ' 02-2697-6333'],
#  ['淡水新市店', ' 新北市淡水區中山北路二段201號 Map', ' 02-2623-9927'],
#  ['蘆洲長榮店', ' 新北市蘆洲區長榮路201號 Map', ' 02-8286-3832']]

# %%
import json
import csv
totalData = []
fp = open("NTC_cama.json", "r", encoding="utf-8")
strJson = fp.read()
fp.close()

# headers = ["name", "address", "phone_num"]
with open('NTC_cama.csv','w', encoding='utf-8', newline='') as f:
    write_csv = csv.writer(f,delimiter=',')
    write_csv.writerows(stbks)

# %%
with open('NTC_cama.csv','r',encoding="utf-8",newline='')as f:
    reader = csv.reader(f,delimiter=',')
    for rows in reader:
        print(rows)
# Out:
# ['四號公園店', ' 新北市中和區中安街24號 Map', ' 02-2929-6691']
# ['中和環球店', ' 新北市中和區中山路三段99號 Map', ' 02-22213588']
# ['中和立言店', ' 新北市中和區中正路903之1號 Map', ' 02-2221-3277']
# ['中和泰和店', ' 新北市中和區泰和街39號1樓 Map', ' 02-2240-3699']
# ['新店七張店', ' 新北市新店區北新路二段218號 Map', ' 02-2910-3508']
# ['新店寶橋店', ' 新北市新店區寶橋路214號 Map', ' 02-2912-9970']
# ['新店民權店', ' 新北市新店區民權路96號1樓 Map', ' 02-2218-5000']
# ['板橋三民店', ' 新北市板橋區三民路二段67號 Map', ' 02-29580101']
# ['板橋三民店', ' 新北市板橋區三民路二段67號1樓 Map', ' 02-2958-0101']
# ['板橋亞東店', ' 新北市板橋區南雅南路二段21號Ｂ1 Map', ' 02-8966-8333']
# ['板橋文化店', ' 新北市板橋區文化路二段402號 Map', ' 02-22586227']
# ['板橋正隆店', ' 新北市板橋區板新路一號 Map', ' 02-2961-6089']
# ['永和中山店', ' 新北市永和區中山路一段220號 Map', ' 02-2231-1119']
# ['永和耕莘店', ' 新北市永和區中興街83號 Map', ' 02-2920-6888']
# ['永和耕莘店', ' 新北市永和區中興街83號1樓 Map', ' 02-29206888']
# ['永和福和店', ' 新北市永和區福和路271號 Map', ' 02-2231-1823']
# ['汐止遠雄店', ' 新北市汐止區新台五路一段99號B1 Map', ' 02-2697-6333']
# ['淡水新市店', ' 新北市淡水區中山北路二段201號 Map', ' 02-2623-9927']
# ['蘆洲長榮店', ' 新北市蘆洲區長榮路201號 Map', ' 02-8286-3832']
